# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
import time
import random

# %%
path = '/media/ubuntu/My Book/data/Chl-a/train/perfect'
imgs = os.listdir(path)
len(imgs)
# Out:
# 63055

# %%
    ind = random.randint(0,18665)
    img = cv2.imread(os.path.join(path, imgs[ind]),cv2.IMREAD_UNCHANGED)
    plt.imshow(img)
    plt.axis(False)
    _ = plt.colorbar()
