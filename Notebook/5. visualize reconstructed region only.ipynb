# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
import time
import random

# %%
path = '/home/juneyonglee/Desktop/AY_ust/model/results/ust_chl_4_perfect/600000/10/recon/'

imgs = os.listdir(path)
len(imgs)    
# ind = random.randint(0,18665)
ind = random.randint(0,18665)
img = cv2.imread(os.path.join(path, imgs[ind]),cv2.IMREAD_UNCHANGED)
plt.imshow(img)
plt.axis(False)
_ = plt.colorbar()
